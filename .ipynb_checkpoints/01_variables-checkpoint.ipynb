# %% [markdown]
# ### Variable Declaration and Print

# %%
a = 5

# %%
b = 10

# %%
print("Sum(a,b)=", a+b)
# Out:
# Sum(a,b)= 15

# %%
name = "Amma"

# %%
sname = "Damma"

# %%
print("full name - ", name + sname)
# Out:
# full name -  AmmaDamma

# %%
print(type(name))
# Out:
# <class 'str'>
