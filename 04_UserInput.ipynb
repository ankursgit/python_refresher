# %% [markdown]
# # User Input

# %% [markdown]
# #### By Default the user input is in the form of Strings

# %%
a = input("Enter the value of a")
# Out:
# Enter the value of a 10

# %%
b = int(input("Enter the values of b"))
# Out:
# Enter the values of b 5

# %%
c = int(a) + b

print("a+b=", c)
# Out:
# a+b= 15
